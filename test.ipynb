# %% [markdown]
# <a href="https://colab.research.google.com/github/tomasyeo/colab_experiment/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'
